# %%
import random
import math
import datetime
import pandas as pd
import matplotlib.pyplot as plt

# --- Bài 1 ---
print("--- Bài 1 ---")
# a = float(input("Nhập giá trị a: ")) # Tạm comment để bạn dễ copy chạy thử
# b = float(input("Nhập giá trị b: "))
a, b = 10, 5 # Ví dụ giá trị

print(f"Tổng: {a + b} | Hiệu: {a - b} | Tích: {a * b}")
if b != 0:
    print(f"Thương: {a / b}")
else:
    print("Không thể chia cho 0!")
# --- Yêu cầu 2: Lấy các ký tự từ chỉ số 2 đến 4 (llo) ---
print("\n--- Bài 2 ---")
chuoi_1 = "Hello World"
# Lưu ý: Trong Python, cú pháp cắt chuỗi [2:5] sẽ lấy các ký tự ở vị trí 2, 3 và 4.
ket_qua_cat = chuoi_1[2:5] 
print(f"Các ký tự từ chỉ số 2 đến 4 của '{chuoi_1}' là: {ket_qua_cat}")

# --- Yêu cầu 3: Xử lý khoảng trắng, hoa/thường và thay thế ký tự ---
print("\n--- Bài 3 ---")
chuoi_2 = " Hello World "

# Xóa khoảng trắng thừa ở 2 đầu
chuoi_chuan = chuoi_2.strip()
print(f"Chuỗi sau khi xóa khoảng trắng: '{chuoi_chuan}'")

# Chuyển sang in hoa và in thường
print(f"Chuỗi in hoa: {chuoi_chuan.upper()}")
print(f"Chuỗi in thường: {chuoi_chuan.lower()}")

# Thay ký tự 'H' thành 'J'
chuoi_thay_the = chuoi_chuan.replace('H', 'J')
print(f"Chuỗi sau khi thay 'H' thành 'J': {chuoi_thay_the}")

# --- Yêu cầu 4: In "Hello World!" nếu a > b ---
print("\n--- Bài 4 ---")
if a > b:
    print("Hello World!")

# --- Bài 5 (SỬA LỖI THỤT LỀ) ---
print("\n--- Bài 5 ---")
if a == b:
    print("Yes")
else:
    print("No")  # Đã sửa thụt lề ở đây
    
--6) 
# Giả sử ta có các biến sau để chạy thử nghiệm
a, b, c, d = 5, 5, 3, 5

print("--- Bài 6 ---")
if a == b:
    print(1)
elif a > b:
    print(2)
else:
    print(3)

print("\n--- Bài 7 ---")
if a == b and b == d:
    print("Hello World!")

print("\n--- Bài 8 ---")
if a == b or c == d:
    print("Hello World!")

print("\n--- Bài 9: Cú pháp if...else trên 1 dòng ---")
# Cú pháp: Giá_trị_khi_Đúng if Điều_kiện else Giá_trị_khi_Sai
# Ví dụ thay thế cho: if a > b: max_val = a else: max_val = b
max_val = a if a > b else b
print(f"Giá trị lớn nhất giữa a và b là: {max_val}")

print("\n--- Bài 10 ---")
# Nhập lại a và b cho bài 10
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
print("Kết quả câu lệnh: ", end="")
# Câu lệnh này thực hiện: in "A" nếu a>b, in "=" nếu a==b, ngược lại (a<b) in "B"
print("A") if a > b else print("=") if a == b else print("B")
10)
11)
import random

print("\n--- Bài 11 ---")
n = int(input("Nhập số phần tử của mảng a: "))
# Tạo mảng a với n phần tử ngẫu nhiên từ 1 đến 100
a_arr = [random.randint(1, 100) for _ in range(n)]
# Tạo mảng b chỉ chứa các phần tử chẵn của a
b_arr = [x for x in a_arr if x % 2 == 0]

print(f"Mảng a: {a_arr}")
print(f"Mảng b (các số chẵn): {b_arr}")

print("\n--- Bài 12 ---")
# Tính tổng các số từ 0 đến 999 là bội của 3 hoặc 5
tong = sum(x for x in range(1000) if x % 3 == 0 or x % 5 == 0)
print(f"Tổng các số < 1000 là bội của 3 hoặc 5: {tong}")

print("\n--- Bài 13 ---")
def tron_mang(mang1, mang2):
    ket_qua = []
    # Lấy chiều dài của mảng dài hơn
    max_len = max(len(mang1), len(mang2))
    
    for i in range(max_len):
        # Nếu i vẫn nằm trong giới hạn của mảng thì lấy giá trị, ngược lại coi là 0
        val1 = mang1[i] if i < len(mang1) else 0
        val2 = mang2[i] if i < len(mang2) else 0
        ket_qua.append(val1 + val2)
        
    return ket_qua

mang_a_13 = [3, 9, 1, 4]
mang_b_13 = [2, 7, 4, 3, 2, 8]
print(f"Kết quả trộn mảng: {tron_mang(mang_a_13, mang_b_13)}")
--13)
14)
import random
import math

print("\n--- Bài 14 ---")
m = int(input("Nhập số dòng m: "))
n = int(input("Nhập số cột n: "))

# a. Tạo mảng a chứa các số nguyên ngẫu nhiên (từ 1 đến 10) để dễ tính toán
matrix = [[random.randint(1, 10) for _ in range(n)] for _ in range(m)]

print("Mảng 2 chiều đã tạo:")
for row in matrix:
    print(row)

# b. Xuất các phần tử thuộc dòng k
k_row = int(input(f"Nhập dòng k muốn xuất (0 đến {m-1}): "))
print(f"Các phần tử thuộc dòng {k_row}: {matrix[k_row]}")

# c. Xuất các phần tử thuộc cột k
k_col = int(input(f"Nhập cột k muốn xuất (0 đến {n-1}): "))
col_elements = [row[k_col] for row in matrix]
print(f"Các phần tử thuộc cột {k_col}: {col_elements}")

# d. Tìm dòng có tổng lớn nhất
max_sum_row = max(matrix, key=sum)
print(f"Dòng có tổng lớn nhất: {max_sum_row} (Tổng = {sum(max_sum_row)})")

# e. Tìm cột có tích nhỏ nhất
def tich_cot(col_idx):
    return math.prod(row[col_idx] for row in matrix)

min_prod_col_idx = min(range(n), key=tich_cot)
print(f"Cột có tích nhỏ nhất là cột {min_prod_col_idx} (Tích = {tich_cot(min_prod_col_idx)})")

# f. Xuất phần tử thuộc dòng chẵn (index % 2 == 0) và cột lẻ (index % 2 != 0)
print("Các phần tử thuộc dòng chẵn, cột lẻ:")
for i in range(m):
    for j in range(n):
        if i % 2 == 0 and j % 2 != 0:
            print(f"A[{i}][{j}] = {matrix[i][j]}", end=" | ")
print() # Xuống dòng

# g. Tính trung bình cộng phần tử chẵn thuộc dòng lẻ
pt_chan_dong_le = []
for i in range(m):
    if i % 2 != 0: # Dòng lẻ
        for j in range(n):
            if matrix[i][j] % 2 == 0: # Phần tử chẵn
                pt_chan_dong_le.append(matrix[i][j])

if pt_chan_dong_le:
    tbc_g = sum(pt_chan_dong_le) / len(pt_chan_dong_le)
    print(f"TBC các phần tử chẵn thuộc dòng lẻ: {tbc_g}")
else:
    print("Không có phần tử chẵn nào nằm trên dòng lẻ.")

# h. Tính trung bình cộng các phần tử thuộc biên
pt_bien = []
for i in range(m):
    for j in range(n):
        # Thuộc biên nếu nằm ở dòng đầu, dòng cuối, cột đầu hoặc cột cuối
        if i == 0 or i == m - 1 or j == 0 or j == n - 1:
            pt_bien.append(matrix[i][j])

if pt_bien:
    tbc_h = sum(pt_bien) / len(pt_bien)
    print(f"TBC các phần tử biên: {tbc_h}")
15)

import datetime

# --- Bài 15 (SỬA LỖI THỤT LỀ CÂU G) ---
class SinhVien:
    def __init__(self, ma_sv, ten, nam_sinh, diem_tb):
        self.ma_sv = str(ma_sv)[:10]
        self.ten = str(ten)[:20]
        self.nam_sinh = int(nam_sinh)
        self.diem_tb = float(diem_tb)

def dem_sv_ho_phan(ds):
    # Đã sửa thụt lề câu lệnh return dưới đây
    return sum(1 for sv in ds if sv.ten.split()[0].upper() == "PHAN")

# b. Khởi tạo một mảng có n sinh viên
danh_sach_sv = [
    SinhVien("02DH0001", "Phan Thi Lan", 2004, 7.5),
    SinhVien("01CD0002", "Nguyen Van A", 2007, 4.0),
    SinhVien("03DH0003", "Phan Van B", 2003, 8.0),
    SinhVien("04DH0004", "Le Thi Lan", 2006, 5.5)
]

# c. Đếm SV đủ điều kiện lên lớp (Điểm TB >= 5)
def dem_sv_len_lop(ds):
    return sum(1 for sv in ds if sv.diem_tb >= 5)

# d. Xuất các sinh viên đủ 20 tuổi
def xuat_sv_20_tuoi(ds):
    nam_hien_tai = datetime.date.today().year
    print("Các sinh viên đủ 20 tuổi:")
    for sv in ds:
        if (nam_hien_tai - sv.nam_sinh) >= 20:
            print(f"- {sv.ten}")

# e. Đếm số SV hệ đại học (Mã chứa 'DH' ở vị trí 2,3)
# Lưu ý: Index trong Python bắt đầu từ 0. Vị trí 2, 3 tương ứng với index 2 và 3.
def dem_sv_he_dh(ds):
    return sum(1 for sv in ds if len(sv.ma_sv) >= 4 and sv.ma_sv[2:4] == "DH")

# f. Đếm sinh viên có tên "Lan" (Từ cuối cùng trong chuỗi tên)
def dem_sv_ten_lan(ds):
    return sum(1 for sv in ds if sv.ten.split()[-1].upper() == "LAN")

# g. Đếm sinh viên có họ "Phan" (Từ đầu tiên trong chuỗi tên)
def dem_sv_ho_phan(ds):
return sum(1 for sv in ds if sv.ten.split()[0].upper() == "PHAN")
II) Bài Tập về nhà:
4)

# Ghi dữ liệu vào file (Xuất file)
with open("input.txt", "w", encoding="utf-8") as file:
    file.write("Dữ liệu thử nghiệm xử lý I/O\n")
    file.write("Dòng thứ hai trong file.")

# Đọc dữ liệu từ file
with open("input.txt", "r", encoding="utf-8") as file:
    noi_dung = file.read()
print("Nội dung file:\n", noi_dung)
5)

import pandas as pd
import matplotlib.pyplot as plt

# 1. Dùng Pandas tạo DataFrame (bảng dữ liệu)
data = {
    'Môn học': ['CSDL', 'Hệ Điều Hành', 'Trí Tuệ Nhân Tạo', 'Xác Suất'],
    'Điểm Số': [8.5, 7.0, 9.0, 6.5]
}
df = pd.DataFrame(data)
print("Bảng điểm Pandas:")
print(df)

# 2. Dùng Matplotlib vẽ biểu đồ cột từ DataFrame đó
plt.bar(df['Môn học'], df['Điểm Số'], color='coral')
plt.title('Điểm số các môn chuyên ngành')
plt.xlabel('Môn học')
plt.ylabel('Điểm')
plt.ylim(0, 10) # Giới hạn thang điểm từ 0-10
plt.show()
3)
he_thong_game = {
    "nguoi_choi_1": {"ten": "Alice", "cap_do": 15, "vu_khi": "Kiếm"},
    "nguoi_choi_2": {"ten": "Bob", "cap_do": 20, "vu_khi": "Cung"},
    "nguoi_choi_3": {"ten": "Charlie", "cap_do": 12, "vu_khi": "Phép"}
}
2)
def cheo_phu_giam_dan(a, n):
    for i in range(n - 1):
        if a[i][n - 1 - i] <= a[i + 1][n - 2 - i]:
            return False
    return True # Đã sửa thụt lề để nằm TRONG hàm

# b. Chuyển phần tử âm thành trị tuyệt đối (Dùng cho ma trận m x n)
def tri_tuyet_doi(a, m, n):
    for i in range(m):
        for j in range(n):
            a[i][j] = abs(a[i][j])
    return a

# c. Thay phần tử chẵn bằng x (Dùng cho ma trận m x n)
def thay_chan_bang_x(a, m, n, x):
    for i in range(m):
        for j in range(n):
            if a[i][j] % 2 == 0:
                a[i][j] = x
    return a

# d. Kiểm tra ma trận toàn chẵn không
def kiem_tra_toan_chan(a, m, n):
    for i in range(m):
        for j in range(n):
            if a[i][j] % 2 != 0:
                return False
    return True

# e. Kiểm tra ma trận đối xứng (a[i][j] == a[j][i])
def kiem_tra_doi_xung(a, n):
    for i in range(n):
        for j in range(i, n): # Chỉ cần duyệt 1 nửa tam giác
            if a[i][j] != a[j][i]:
                return False
    return True

# f. Kiểm tra đường chéo chính tăng dần (a[i][i] < a[i+1][i+1])
def cheo_chinh_tang_dan(a, n):
    for i in range(n - 1):
        if a[i][i] >= a[i+1][i+1]:
            return False
    return True

# g. Xuất tam giác dưới đường chéo phụ (i + j >= n - 1)
def xuat_tam_giac_duoi_cheo_phu(a, n):
    for i in range(n):
        for j in range(n):
            if i + j >= n - 1:
                print(a[i][j], end="\t")
            else:
                print(" \t", end="") # In khoảng trắng để giữ form ma trận
        print()

# h. Kiểm tra đường chéo phụ giảm dần
def cheo_phu_giam_dan(a, n):
    for i in range(n - 1):
        # So sánh phần tử hiện tại với phần tử chéo phụ tiếp theo
        if a[i][n - 1 - i] <= a[i + 1][n - 2 - i]:
            return False
return True
1)
def tron_mang_min(a, b):
    ket_qua = []
    min_len = min(len(a), len(b))
    
    # Lấy min của 2 phần tử tương ứng
    for i in range(min_len):
        ket_qua.append(min(a[i], b[i]))
        
    # Nối các phần tử còn dư của mảng dài hơn
    if len(a) > len(b):
        ket_qua.extend(a[min_len:])
    else:
        ket_qua.extend(b[min_len:])
        
    return ket_qua

# Ví dụ của bạn:
# print(tron_mang_min([3, 9, 1, 4], [2, 7, 4, 3, 2, 8])) 
# Kết quả: [2, 7, 1, 3, 2, 8]
# Out:
#   Cell In[6], line 53
#     --6)
#        ^
# SyntaxError: unmatched ')'
